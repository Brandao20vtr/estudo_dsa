# %%
# IF, ELSE, ELIF COM PYTHON

# %%
# Condicional If

if 5 > 2:   # se (5) for maior que (2), execute esta mensagem.
    print('Eu sou o Vitor.')

# %%
if 5 < 2:
    print('Eu sou o Vitor.')
else:
        print('Eu não sou o Vitor.')

# %%
if 5 == 5:   # Para ver a igualdade eu preciso SEMPRE usar (==).
    print('Você está certo!')

# %%
# CONDICIONAIS ANINHADOS

# %%
idade = 18
if idade > 17:
    print('Você é jovem.')

# %%
Nome = 'Vitor'

if idade > 13:
    if Nome == 'Vitor':
        print('Okay Vitor, você pode entrar.')
    else:
        print('Desculpe, você não pode entrar.')

# %%
idade = 13
Nome = 'Vitor'

if idade >= 13 and Nome == 'Vitor':   # Operador lógino (and) = E.
    print('Okay Vitor, você tem autorização para entrar.')

# %%
idade = 12
Nome = 'Vitor'

if (idade >= 13) or (Nome == 'Vitor'):   # Operador lógino (or) = OU.
    print('Okay Vitor, você tem autorização para entrar.')

# %%
###  ELIF  ### - Evitar a escrita de vários IFs aninhados.

# %%
dia = 'Terça'

if dia == 'Segunda':
    print('Hoje fará sol!')
else:
    print('Hoje vai chover!')

# %%
if dia == 'Segunda':
    print('Hoje fará sol!')
elif dia == 'Terça':
    print('Hoje vai chover!')
else:
    print('Sem previsão de tempo para o dia selecionado.')

# %%
# OPERADORES LÓGICOS

# %%
idade = 18
Nome = 'Vitor'

if idade > 17:
    print('Você pode dirigir.')

# %%
idade = 18

if idade > 17 and Nome == 'Vitor':   # O objetivo do operador é verificar se estas duas confições estão corretas.
    print('Você está autorizado.')

# %%
disciplina = input('Digite o nome da disciplina: ')
nota_final = input('Digite sua note final entre (0 e 100): ')

if disciplina == 'Geografia' and nota_final >= '70':
    print('Você foi aprovado!')
else:
    print('Você foi reprovado! Precisa estudar mais!')

# %%
disciplina = input('Digite o nome da disciplina: ')
nota_final = input('Digite sua note final entre (0 e 100): ')
semestre = input('Digite o seu semestre (1 a 4): ')

if disciplina == 'Geografia' and nota_final >= '50' and int(semestre) != 1:
    print('Você foi aprovado en %s com média final %r!' %(disciplina, nota_final))
else:
    print('Você foi reprovado! Precisa estudar mais!')
